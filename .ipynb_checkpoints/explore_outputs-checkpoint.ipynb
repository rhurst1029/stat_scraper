# %%
import pandas as pd

# %%
pd.read_csv('player_stats_SRB_HUN.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-35f27de29dd0> in <module>
# ----> 1 pd.read_csv('player_stats_SRB_HUN.csv',as_index = False)
#
# TypeError: read_csv() got an unexpected keyword argument 'as_index'
